# %% [markdown]
# # Best window's size

# %% [markdown]
# ## 0. Data

# %%
from recommender_system import RedSQL, load_cfg
from mab import get_bandits_events
import time

# %%
t1=time.time()

cfg = load_cfg()

# %%
with RedSQL(cfg['redshift']) as rs:
    data = get_bandits_events(rs)

t2=time.time()
print(t2-t1)
# Out:
# 175.717351436615

# %% [markdown]
# ## 1. Window size

# %% [markdown]
# When evaluating recommender systems, the quality of data should be taken into account. In our case we use only (the most) recent part of the dataset.
# We do this through a sliding window of size $n$, which influences both the optimal performance of individual algorithms and comparisons between algorithms (Verachtert et al., 2022).

# %%
import matplotlib.pyplot as plt
from matplotlib.dates import MonthLocator, YearLocator, DayLocator, WeekdayLocator
import numpy as np
import datetime

from collections import Counter

from mab import compute_bandit_metrics, compute_pulls
from mab.tag import TypeTag

# %%
def display_activity(pulls, time_pattern='%Y-%m-%d'):
    fig, ax = plt.subplots(1, 1)
    for tag, stats in pulls.items():             #tag=key, stats=value
        activity = sorted([(k, v) for k, v in Counter(t.strftime(time_pattern)
                                    for t in stats['time']).items()])
        days = [datetime.datetime.strptime(t[0], time_pattern) for t in activity]
        recs = [t[1] for t in activity]
        ax.plot(days, recs, label=tag)
    plt.ylim([0, None])
    plt.xlim([days[0], days[-1]])
    plt.legend()
    plt.ylabel('Recommendations')
    plt.xlabel('Time')
    fig.autofmt_xdate()
    ax.xaxis.set_major_locator(WeekdayLocator())
    ax.xaxis.set_minor_locator(DayLocator())
    ax.grid(True)
    plt.show()

# %% [markdown]
# ### 1.1 Quantity

# %%
# Global analysis, i.e. keeping eventPeople, Planning, Product, ... altogether (which corresponds to "Per algorithm" since there's no bandit monitoring yet)

pulls = compute_pulls(data, store_time=True)
pulls
# Out:
# {'version-v2.3.0': {'success': [False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    True,
#    False,
#    False,
#    False,
#    True,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    True,
#    False,
#    False,
#    True,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    True,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    True,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    True,
#    False,
#    False,
#    False,
#    False,
#    False,
#    True,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    True,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    True,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    True,
#    True,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    True,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    True,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    True,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    True,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    True,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    True,
#    True,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    True,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    True,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    True,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    True,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    True,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    True,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    True,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    True,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    False,
#    ...],
#   'time': [datetime.datetime(2024, 9, 23, 19, 28, 14, 293059, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 28, 14, 524818, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 28, 15, 164782, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 28, 15, 582469, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 28, 15, 663178, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 28, 16, 801822, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 28, 17, 383766, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 28, 17, 580871, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 28, 18, 686048, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 28, 19, 543148, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 28, 19, 880660, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 28, 20, 847759, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 28, 21, 646409, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 28, 22, 550772, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 28, 22, 742895, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 28, 24, 486347, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 28, 25, 887686, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 28, 26, 719233, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 28, 27, 536559, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 28, 27, 713494, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 28, 28, 392780, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 28, 31, 610763, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 28, 32, 975276, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 28, 34, 96978, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 28, 34, 499446, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 28, 34, 669422, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 28, 34, 784393, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 28, 37, 433045, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 28, 38, 560970, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 28, 38, 660149, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 28, 39, 69079, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 28, 39, 566071, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 28, 39, 908934, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 28, 40, 315171, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 28, 42, 9476, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 28, 42, 15801, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 28, 45, 113393, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 28, 46, 274772, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 28, 46, 592495, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 28, 47, 6563, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 28, 48, 214885, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 28, 48, 939885, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 28, 49, 259864, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 28, 50, 316432, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 28, 50, 321536, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 28, 50, 838048, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 28, 51, 894157, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 28, 52, 37072, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 28, 52, 433230, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 28, 52, 521810, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 28, 53, 686914, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 28, 54, 55192, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 28, 54, 399294, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 28, 55, 157863, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 28, 56, 82066, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 28, 56, 767340, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 28, 56, 773554, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 28, 57, 38302, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 28, 59, 149036, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 29, 1, 542097, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 29, 3, 139853, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 29, 3, 155254, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 29, 4, 757684, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 29, 4, 991078, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 29, 5, 183177, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 29, 5, 548725, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 29, 6, 43432, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 29, 6, 158709, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 29, 6, 759867, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 29, 6, 765387, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 29, 7, 133171, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 29, 7, 376989, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 29, 7, 690209, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 29, 9, 817588, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 29, 9, 876850, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 29, 10, 871102, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 29, 11, 266017, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 29, 11, 508702, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 29, 11, 713811, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 29, 12, 98828, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 29, 16, 334776, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 29, 16, 788956, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 29, 17, 542870, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 29, 20, 436534, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 29,
tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 7, 908660, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 9, 472549, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 10, 930814, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 13, 686576, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 13, 694942, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 14, 229912, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 15, 19192, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 15, 235136, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 15, 502835, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 15, 687767, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 15, 884390, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 16, 348524, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 16, 878304, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 17, 27198, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 17, 452729, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 17, 892658, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 18, 263451, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 18, 493038, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 20, 157688, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 20, 218864, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 20, 350689, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 22, 268286, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 23, 42114, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 23, 614194, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 23, 705284, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 24, 734772, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 25, 435230, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 25, 842922, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 25, 901567, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 25, 997387, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 26, 378701, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 26, 899414, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 27, 748691, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 27, 936801, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 28, 278484, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 28, 681999, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 29, 240654, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 29, 296457, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 29, 750374, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 29, 957663, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 30, 424528, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 30, 626952, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 31, 107473, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 31, 235263, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 32, 302083, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 32, 727643, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 33, 55464, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 33, 644092, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 33, 896762, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 34, 1600, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 34, 462854, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 34, 535729, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 35, 650335, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 36, 262646, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 36, 365620, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 36, 807555, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 37, 835588, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 38, 77093, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 38, 454234, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 38, 722592, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 39, 847635, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 41, 504408, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 41, 531004, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 42, 414521, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 43, 759774, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 43, 982589, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 44, 148705, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 44, 921232, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 45, 834093, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 46, 254793, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 47, 228560, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 47, 587687, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 48, 123996, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 48, 225283, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 48, 636543, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 48, 866397, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 49, 374209, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 49, 419293, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 49, 432597, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 50, 134773, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 50, 275946, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 51, 676105, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 52, 8496, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 52, 119118, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 52, 302477, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 52, 580884, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 52, 986327, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 54, 340834, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 54, 660687, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 55, 215238, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 55, 392969, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 56, 353116, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 56, 613529, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 56, 617888, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 56, 830464, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 57, 41345, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 58, 605728, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 59, 422060, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 39, 59, 662516, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 1, 55018, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 1, 174529, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 1, 803107, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 2, 750190, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 2, 812894, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 3, 742972, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 4, 970066, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 6, 573994, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 6, 894708, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 7, 286442, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 7, 333989, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 7, 683135, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 9, 499111, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 9, 768390, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 10, 771860, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 10, 816493, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 11, 701454, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 12, 551870, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 12, 664381, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 13, 80538, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 14, 498079, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 15, 816718, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 15, 891103, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 15, 896821, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 16, 50858, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 16, 558923, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 17, 823945, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 18, 186782, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 18, 314455, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 20, 525477, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 21, 787714, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 21, 915007, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 23, 163750, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 23, 715089, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 23, 994417, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 25, 208967, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 26, 163948, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 26, 172873, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 26, 350583, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 28, 272480, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 28, 305344, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 29, 110079, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 29, 420326, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 29, 459547, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 29, 503316, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 29, 953503, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 31, 90916, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 32, 112748, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 32, 411923, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 32, 665533, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 32, 844273, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 33, 252661, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 33, 964494, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 34, 161802, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 35, 568799, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 36, 58174, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 37, 639477, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 37, 756523, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 38, 705356, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 38, 746895, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 39, 306097, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 39, 754297, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 39, 936500, tzinfo=datetime.timezone.utc),
#    datetime.datetime(2024, 9, 23, 19, 40, 40, 590440, tzinfo=datetime.timezone.utc),
#    ...]}}

# %%
display_activity(pulls)

# %%
# Per item analysis, i.e. dividing EventPeople, Planning, Product, ...

pulls_type = compute_pulls(data, tag_extractor=TypeTag(), store_time=True)

display_activity(pulls_type)

# %% [markdown]
# ### 1.2 Quality

# %% [markdown]
# We observe the trend of click rates.

# %%
def display_rates(rates, data_name='moving_avg', y_label='Click rate', pruning=400):
    fig, ax = plt.subplots(1, 1)
    for tag, stats in rates.items():
        rate = stats[data_name][::pruning]
        if 'time' in stats:
            ax.plot(stats['time'][::pruning], rate, label=tag)
        else:
            ax.plot(np.linspace(0, 1, len(rate)), rate, label=tag)
    plt.ylim([0, None])
    if 'time' in stats:
        plt.xlim([stats['time'][0], stats['time'][-1]])
        fig.autofmt_xdate()
        ax.xaxis.set_major_locator(WeekdayLocator())
        ax.xaxis.set_minor_locator(DayLocator())
    else:
        plt.xlim([0, 1])
    plt.ylabel(y_label)
    plt.xlabel('Time')
    if len(rates) > 1:
        plt.legend()
    ax.grid(True)
    plt.show()


# I define "geometric_average" which is not the usual geoemtric average (x_1 * ... * x_n)^{1/n},
# but instead the ARITHMETIC average but with parameters rho and 1-rho that corresponds to having weights decreasing with geometric distribution.
# Moving average of binary success data to each tag's statistics in the input dictionary.
# Recent successes have a higher influence, and older successes gradually diminish in impact according to the specified decay rate rho.

def geometric_average(pulls, size=1000):
    rho = 1/size
    for tag, stats in pulls.items():
        successes = stats['success']
        moving_avg = np.zeros(len(successes))                             # n-day moving average = average value in the last n-days period
        for i, s in enumerate(successes):
            moving_avg[i] = (1-rho) * moving_avg[i-1] + rho * int(s)
        pulls[tag]['moving_avg'] = moving_avg


# In order to take into account only what happens now, not old events that would not give a true estimation of what is happening in present time
# Doesn't return anything but modifies pulls (inplace)

        
# Here time window is expressed in number of actions (because simpler) =?
# If you have ideas to auto-tune the average computation, you are welcome =?

# %%
# TIME: Global analysis

pulls = compute_pulls(data, store_time=True)

geometric_average(pulls, size=5*10**2)
display_rates(pulls)

# Click rate between 1% and 12%. Precise plot but too noisy

# %%
geometric_average(pulls, size=10**4)
display_rates(pulls)
# Clearer

# %%
# Increasing "size" from 10**4 to 10**5, i.e. decreasing frequency, stretches the graph horizontally

geometric_average(pulls, size=10**5)
display_rates(pulls)

# I notice that the click rate (i.e. the quality of recommendation) is generally between 3 and 5% (quite low, could definitely be improved)
# By increazing the size, the click-through rate gets smoothed (before 0.065, now 0.045), but we notice that in recent time the click-through rate is preserved

# %%
geometric_average(pulls, size=2.5*10**5)
display_rates(pulls)
# Definitely too much: for n larger than 10**5 we do not have anymore a clead idea of what is going on, and only recent click-rates are reliable

# %% [markdown]
# Hence, size $10^5$ is a sweet spot in the trade-off between stability of the average and reactivity to changes.

# %%
# TIME: Per item analysis

geometric_average(pulls_type, size=3000)
display_rates(pulls_type)

# %%
geometric_average(pulls_type, size=3*10**4)         #3*10**4 is enough
display_rates(pulls_type)

# The tendency is modified, as the click-through rate gets smoothed. In moving average, you discard the frequencies higher than your moving window to gain in visibility.
# The activity of products (red) is really low, so the characteristic time window for them is much larger than for the rest. This justify the different tendency of that line.

# %% [markdown]
# ### 2. Weeks

# %% [markdown]
# Following our consideration on weekly patterns, we want to better investigate it, in order to find the best window size.

# %%
# Example week 

from datetime import datetime, timezone, timedelta

# Date range of the week
start_date = datetime(2024, 9, 23, tzinfo=timezone.utc)
end_date = datetime(2024, 9, 30, tzinfo=timezone.utc)

# Extract pulls
success_list = pulls['version-v2.3.0']['success']
time_list = pulls['version-v2.3.0']['time']

# Count pulls which succeeded in the selected week 
count_succ = sum(
    success and start_date <= time <= end_date
    for success, time in zip(success_list, time_list)
)

# Count total pulls in the selected week 
count_pull = sum(start_date <= time <= end_date
    for success, time in zip(success_list, time_list))

# CTR in the selected week 
ctr=count_succ/count_pull

print(f"{start_date.date()} to {end_date.date()} (excluded): {count_succ} successes, {count_pull} pulls, {ctr} click-through rate")

# 23-29/09/2024: 21063 successes, 490953 total pulls, 4.29% click-through rate
# Out:
# 2024-09-23 to 2024-09-30 (excluded): 21063 successes, 490953 pulls, 0.04290227374107094 click-through rate

# %%
# Pulls for each week 

from datetime import datetime, timezone, timedelta

def count_pulls_per_week(pulls, start_date, end_date):
   
    # Extract time list from the data
    time_list = pulls['version-v2.3.0']['time']
    
    # Initialize a dictionary to store the results
    weekly_counts = {}
    
    # Define the current week range
    current_start_date = start_date
    current_end_date = start_date + timedelta(days=7)
    
    while current_start_date < end_date:
        # Count pulls in the current week
        count = sum(
            current_start_date <= time < current_end_date
            for time in time_list
        )
        
        # Store the result with the week's start date as the key
        weekly_counts[current_start_date] = count
        
        # Move to the next week
        current_start_date = current_end_date
        current_end_date += timedelta(days=7)

    # Dictionary with week start dates as keys and pull counts as values.
    return weekly_counts

# %%
# Count of pulls for each week 

# Define the date range
start_date = datetime(2024, 9, 23, tzinfo=timezone.utc)
end_date = datetime(2024, 11, 22, tzinfo=timezone.utc)

# Call the function
weekly_pulls = count_pulls_per_week(pulls, start_date, end_date)

# Print the results
for week_start, count in weekly_pulls.items():
    print(f"{week_start.date()} to {(week_start+ timedelta(days=7)).date()} (excluded): {count} pulls")
# Out:
# 2024-09-23 to 2024-09-30 (excluded): 490953 pulls
# 2024-09-30 to 2024-10-07 (excluded): 450481 pulls
# 2024-10-07 to 2024-10-14 (excluded): 468659 pulls
# 2024-10-14 to 2024-10-21 (excluded): 428168 pulls
# 2024-10-21 to 2024-10-28 (excluded): 392092 pulls
# 2024-10-28 to 2024-11-04 (excluded): 239393 pulls
# 2024-11-04 to 2024-11-11 (excluded): 314242 pulls
# 2024-11-11 to 2024-11-18 (excluded): 302551 pulls
# 2024-11-18 to 2024-11-25 (excluded): 169767 pulls

# %%
# Average number of pulls per week

total_pulls = sum(weekly_pulls.values())
num_weeks = len(weekly_pulls)

avg_weekly_pulls = total_pulls / num_weeks if num_weeks > 0 else 0

print(f"Average weekly pulls between {start_date.date()} and {end_date.date()}: {avg_weekly_pulls}")
# Out:
# Average weekly pulls between 2024-09-23 and 2024-11-22: 361811.77777777775

# %% [markdown]
# We have obtained an average of 361812 pulls per week, i.e. about $3.6 \times 10^5$.
# To be more precise, we should have removed the "week" of 18/11 at it is in reality 5 days (due to the period of the data not being an integer number of weeks).

# %%
geometric_average(pulls, size=361812)
display_rates(pulls)

# %% [markdown]
# As suggested before, the click-through rates' plot for such a size is not helpful.
# Hence, we stick to a window size between $10^3$ and $10^5$.

# %% [markdown]
# ## Conclusion and future improvements

# %% [markdown]
# - Instead of using the average number of pulls per week during September-November 2024 as a window size, we opt for a window size between $10^3$ and $10^5$, with a preference towards $10^5$ (resulting in more precise click-through rates).
# - As autumn is the period of the year with more events, a similar analysis could be conduced on more weeks (computational cost allowing) or on a different period of the year, to have a more realistic number of pulls per week of Swapcard's platform.
# - In addition, for small/new users, information is scattered/little, so in these cases we may want to expand the size of the sliding window in order to extract more information. A way to do that could be to adjust the size of the sliding window using a multiplicative parameter (inversely proportional to the degree of activity of users).
